# %% [markdown]
# # Solution Question 2 - Predict class of Iris plant using a neural network

# %% [markdown]
# # Import Libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import random
## importing libraries
 
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold, learning_curve, train_test_split, KFold
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
 
 
# %matplotlib inline

# %%
import tensorflow as tf
from keras import backend as K
import os
import random

def set_seed_for_reproducible_results(seed):
  seed_value= seed
  os.environ['PYTHONHASHSEED']=str(seed_value)
  random.seed(seed_value)
  np.random.seed(seed_value)
  tf.random.set_seed(seed_value)

set_seed_for_reproducible_results(44)

# %% [markdown]
# # STEP 1. Read dataset

# %%
def read_dataset():
  #iris_data= pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')
  iris_data= pd.read_csv('iris.data')
  iris_data.columns=['sepal_length', 'sepal_width', 'petal_length', 'petal_width','species']
  return iris_data

iris_data=read_dataset()
iris_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    149.000000   149.000000    149.000000   149.000000
# mean       5.848322     3.051007      3.774497     1.205369
# std        0.828594     0.433499      1.759651     0.761292
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Step 2 is done after encoding

# %% [markdown]
# # STEP 3. Remove columns that don’t help the problem statement
#
# ## All columns have significant contribution to the classification. Least correlation with target class shown is -0.41 which is also significant. Hence no columns to be dropped. **Correlation plot is generated after encoding in step 4**

# %% [markdown]
# # STEP 4.Encode dataset

# %%
def encodeDataSet(dataset):
  df = dataset.copy()
  Lb = LabelEncoder()
  for features in df.columns:
    df[features] = Lb.fit_transform(df[features])
  df.head()
  return df

iris_data=encodeDataSet(iris_data)

# %% [markdown]
# ## Generating a correlation plot to show significant features

# %%
corr = iris_data.corr()
sns.heatmap(data=corr, square=True , annot=True, cbar=True, linewidths=1.5)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(iris_data,hue="species")
sns.set(style="ticks")
sns.set_palette("husl")

# %% [markdown]
# ### All parameters have significant contribution.
# Nothing to remove

# %% [markdown]
# # STEP 2. Consider all columns as independent variables and assign to variable X except the last column and consider the last column as the dependent variable and assign to variable y.

# %%
  # Splitting the dataset into the Training set and Test set
  # X  are all values except the last column
  X = iris_data.iloc[:, :-1]
  # y = target values, last column of the data frame
  y = iris_data.iloc[:, -1]

# %% [markdown]
# # STEP 6. Split the data into train and test dataset

# %%
(X_train, X_test, y_train, y_test) = train_test_split(X, y,  test_size= 0.2,random_state=72)
print("Training dataset size: %d"% (X_train.shape[0]))
print("Test dataset size: %d"% (X_test.shape[0]))
# Out:
# Training dataset size: 119
# Test dataset size: 30

# %% [markdown]
# # STEP 5. Do Feature Scaling on Independent variables

# %%
from sklearn.preprocessing import StandardScaler
def scale_data(X_train,X_test,col_names):
  sc = StandardScaler()
  X_train = sc.fit_transform(X_train)
  X_test = sc.transform(X_test)
  traindf = pd.DataFrame(X_train, columns = col_names)
  testdf = pd.DataFrame(X_test, columns = col_names)
  return traindf,testdf

X_train, X_test=scale_data(X_train,X_test,X_train.columns)

X_train.hist()
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %% [markdown]
# ## Dataset is prepared after scaling and encoding

# %% [markdown]
# # STEP 7. Use Keras to make the neural network model and train the dataset on the same

# %% [markdown]
# ## STEP 7.1 Create Neural Network model

# %%
from keras.models import Sequential 
from keras.layers import Dense,Activation,Dropout 
from keras.layers.normalization import BatchNormalization 
from keras.utils import np_utils

activation_function="relu"
model=Sequential()
model.add(Dense(50,input_dim=4,activation=activation_function))
model.add(Dense(50,activation=activation_function))
model.add(Dense(30,activation=activation_function))
#model.add(Dropout(0.2))
model.add(Dense(3,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

model.summary()

y_train_ip=np_utils.to_categorical(y_train,num_classes=3)
y_test_ip=np_utils.to_categorical(y_test,num_classes=3)
print(y_train_ip.shape)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 50)                250
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_6 (Dense)              (None, 30)                1530
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 93
# =================================================================
# Total params: 4,423
# Trainable params: 4,423
# Non-trainable params: 0
# _________________________________________________________________
# (119, 3)

# %% [markdown]
# ## STEP 7.2 Training the model

# %%
model.fit(X_train,y_train_ip,batch_size=20,epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 1s 5ms/step - loss: 1.0943 - accuracy: 0.3681
# Epoch 2/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.9985 - accuracy: 0.5044
# Epoch 3/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.8610 - accuracy: 0.6463
# Epoch 4/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.7726 - accuracy: 0.7773
# Epoch 5/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.7086 - accuracy: 0.7650
# Epoch 6/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6176 - accuracy: 0.8271
# Epoch 7/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5249 - accuracy: 0.8680
# Epoch 8/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4974 - accuracy: 0.8452
# Epoch 9/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3786 - accuracy: 0.9359
# Epoch 10/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3294 - accuracy: 0.9345
# Epoch 11/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2741 - accuracy: 0.9620
# Epoch 12/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.2664 - accuracy: 0.9175
# Epoch 13/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1897 - accuracy: 0.9731
# Epoch 14/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1760 - accuracy: 0.9606
# Epoch 15/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1845 - accuracy: 0.9445
# Epoch 16/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1427 - accuracy: 0.9683
# Epoch 17/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1489 - accuracy: 0.9463
# Epoch 18/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1090 - accuracy: 0.9632
# Epoch 19/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.1253 - accuracy: 0.9656
# Epoch 20/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0768 - accuracy: 0.9928
# Epoch 21/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0886 - accuracy: 0.9840
# Epoch 22/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0844 - accuracy: 0.9840
# Epoch 23/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0927 - accuracy: 0.9789
# Epoch 24/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0635 - accuracy: 0.9962
# Epoch 25/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0697 - accuracy: 0.9828
# Epoch 26/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0863 - accuracy: 0.9697
# Epoch 27/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0545 - accuracy: 0.9976
# Epoch 28/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0733 - accuracy: 0.9813
# Epoch 29/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0796 - accuracy: 0.9813
# Epoch 30/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0506 - accuracy: 0.9976
# Epoch 31/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0794 - accuracy: 0.9813
# Epoch 32/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0562 - accuracy: 0.9884
# Epoch 33/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0400 - accuracy: 0.9944
# Epoch 34/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0340 - accuracy: 0.9962
# Epoch 35/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0416 - accuracy: 0.9944
# Epoch 36/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0532 - accuracy: 0.9884
# Epoch 37/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0525 - accuracy: 0.9884
# Epoch 38/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0414 - accuracy: 0.9920
# Epoch 39/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0503 - accuracy: 0.9884
# Epoch 40/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0338 - accuracy: 0.9920
# Epoch 41/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0301 - accuracy: 0.9920
# Epoch 42/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0314 - accuracy: 0.9962
# Epoch 43/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0279 - accuracy: 0.9976
# Epoch 44/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0236 - accuracy: 0.9976
# Epoch 45/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 0.9944
# Epoch 46/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0248 - accuracy: 0.9944
# Epoch 47/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0372 - accuracy: 0.9944
# Epoch 48/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0296 - accuracy: 0.9920
# Epoch 49/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0205 - accuracy: 0.9962
# Epoch 50/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0265 - accuracy: 0.9944
# Epoch 51/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0364 - accuracy: 0.9884
# Epoch 52/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0354 - accuracy: 0.9884
# Epoch 53/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0252 - accuracy: 0.9920
# Epoch 54/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0245 - accuracy: 0.9920
# Epoch 55/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0410 - accuracy: 0.9813
# Epoch 56/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.9976
# Epoch 57/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0229 - accuracy: 0.9944
# Epoch 58/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0253 - accuracy: 0.9920
# Epoch 59/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0386 - accuracy: 0.9813
# Epoch 60/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0330 - accuracy: 0.9884
# Epoch 61/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.9976
# Epoch 62/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 0.9962
# Epoch 63/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0146 - accuracy: 0.9976
# Epoch 64/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0343 - accuracy: 0.9813
# Epoch 65/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0317 - accuracy: 0.9813
# Epoch 66/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0205 - accuracy: 0.9944
# Epoch 67/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 0.9976
# Epoch 68/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0186 - accuracy: 0.9920
# Epoch 69/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0120 - accuracy: 0.9962
# Epoch 70/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0179 - accuracy: 0.9920
# Epoch 71/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0177 - accuracy: 0.9962
# Epoch 72/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0194 - accuracy: 0.9944
# Epoch 73/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0102 - accuracy: 0.9962
# Epoch 74/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0161 - accuracy: 0.9920
# Epoch 75/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0160 - accuracy: 0.9962
# Epoch 76/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0114 - accuracy: 0.9962
# Epoch 77/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0154 - accuracy: 0.9962
# Epoch 78/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 0.9920
# Epoch 79/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0270 - accuracy: 0.9813
# Epoch 80/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 0.9920
# Epoch 81/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.9962
# Epoch 82/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0183 - accuracy: 0.9884
# Epoch 83/100
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0204 - accuracy: 0.9884
# Epoch 84/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 0.9920
# Epoch 85/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0104 - accuracy: 0.9962
# Epoch 86/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0123 - accuracy: 0.9962
# Epoch 87/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0482 - accuracy: 0.95 - 0s 3ms/step - loss: 0.0249 - accuracy: 0.9813
# Epoch 88/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 0.9976
# Epoch 89/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.9920
# Epoch 90/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0128 - accuracy: 0.9976
# Epoch 91/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 0.9962
# Epoch 92/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0206 - accuracy: 0.9884
# Epoch 93/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 94/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0228 - accuracy: 1.0000
# Epoch 95/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 0.9884
# Epoch 96/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0222 - accuracy: 0.9813
# Epoch 97/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0102 - accuracy: 0.9920
# Epoch 98/100
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 0.9884
# Epoch 99/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0205 - accuracy: 0.9813
# Epoch 100/100
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 1.0000

# %% [markdown]
# ## Training complete. Training accuracy: **99%** (approx)

# %% [markdown]
# # STEP 8. Compute the accuracy and precision

# %%
loss, accuracy = model.evaluate( X_test, y_test_ip)
print("Accuracy of the dataset",accuracy )
# Out:
# 1/1 [==============================] - 1s 517ms/step - loss: 0.1130 - accuracy: 0.9667
# Accuracy of the dataset 0.9666666388511658

# %%
from sklearn.metrics import classification_report

pred = model.predict(X_test, batch_size=32, verbose=1)
predicted = np.argmax(pred, axis=1)
report = classification_report(np.argmax(y_test_ip, axis=1), predicted)
print(report)
# Out:
# 1/1 [==============================] - 0s 158ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.89      1.00      0.94         8
#            2       1.00      0.89      0.94         9
#
#     accuracy                           0.97        30
#    macro avg       0.96      0.96      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# # Accuracy (Validation data) = **97 %**
# # Precision (Class 0,1,2) = **(1.0,0.89,1.0)**
